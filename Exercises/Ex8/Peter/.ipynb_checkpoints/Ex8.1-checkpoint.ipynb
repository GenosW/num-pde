# %%
import netgen.gui
from ngsolve import *
import numpy as np
from time import time
import matplotlib.pyplot as plt

from ngsolve.solvers import CG
from ngsolve.la import EigenValues_Preconditioner

# %%
from netgen.geom2d import unit_square
# Why that specific h?
h = 0.01
mesh = Mesh(unit_square.GenerateMesh(maxh=h))
Draw (mesh)

# %%
fes = H1(mesh, order=3,dirichlet=".*") # dirichlet on all boundaries
gfu_a = GridFunction(fes,name = "u_a")
gfu_b = GridFunction(fes,name = "u_b")

# %%
#### Without preconditioner #####
# Eq a)
ua = fes.TrialFunction()
va = fes.TestFunction()

Aa = BilinearForm(fes)
Fa = LinearForm(fes)
Aa += ua*va*dx
Fa += va*dx

Aa.Assemble()
Fa.Assemble()

aruntime_without_precond = time()
with TaskManager():
    gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec
aruntime_without_precond = time() - aruntime_without_precond

# Eq b)
ub = fes.TrialFunction()
vb = fes.TestFunction()

Ab = BilinearForm(fes)
Fb = LinearForm(fes)
Ab += grad(ub)*grad(vb)*dx
Fb += vb*dx

Ab.Assemble()
Fb.Assemble()

bruntime_without_precond = time()
with TaskManager():
    gfu_b.vec.data = Ab.mat.Inverse(fes.FreeDofs()) * Fb.vec
bruntime_without_precond = time() - bruntime_without_precond

    
Draw(gfu_a, mesh, "no precond")
Draw(gfu_b, mesh, "no precond")

# %%
##### WITH Preconditioner
# Eq a)
ua = fes.TrialFunction()
va = fes.TestFunction()

Aa = BilinearForm(fes)
Fa = LinearForm(fes)

Aa += ua*va*dx

Fa += va*dx

Aa.Assemble()
Fa.Assemble()

aruntime_precond_setup = time()
# Jacobi preconditioner
#                  Aa...bilinear form
c = Preconditioner(Aa,"local",test = True)
c.Update()
aruntime_precond_setup = time() - aruntime_precond_setup

aruntime_with_precond = time()
with TaskManager():
    #gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec
    CG (mat=Aa.mat, pre=c.mat, rhs=Fa.vec, sol=gfu_a.vec, printrates=True, maxsteps=10000,tol=1e-9)
aruntime_with_precond = time() - aruntime_with_precond
    
# Eq b)
ub = fes.TrialFunction()
vb = fes.TestFunction()

Ab = BilinearForm(fes)
Fb = LinearForm(fes)

Ab += grad(ub)*grad(vb)*dx

Fb += vb*dx

Ab.Assemble()
Fb.Assemble()

bruntime_precond_setup = time()
# Jacobi preconditioner
#                  Aa...bilinear form
cb = Preconditioner(Ab,"local",test = True)
cb.Update()
bruntime_precond_setup = time() - bruntime_precond_setup

bruntime_with_precond = time()
with TaskManager():
    #gfu_b.vec.data = Ab.mat.Inverse(fes.FreeDofs()) * Fb.vec
    CG (mat=Ab.mat, pre=cb.mat, rhs=Fb.vec, sol=gfu_b.vec,printrates=True, maxsteps=10000,tol=1e-9)
bruntime_with_precond = time() - bruntime_with_precond


Draw(gfu_a, mesh, "precond")
Draw(gfu_b, mesh, "precond")
# Out:
# iteration 0 error = 2.1284679550020535
# iteration 1 error = 0.11470486792385244
# iteration 2 error = 0.1263220504049782
# iteration 3 error = 0.1261223246854291
# iteration 4 error = 0.07177830429838801
# iteration 5 error = 0.030077206351151877
# iteration 6 error = 0.013849236358053619
# iteration 7 error = 0.009783054637130922
# iteration 8 error = 0.012907866878931275
# iteration 9 error = 0.021591129163241223
# iteration 10 error = 0.027417305445015507
# iteration 11 error = 0.01869437447610635
# iteration 12 error = 0.011930857261126413
# iteration 13 error = 0.010396144312984123
# iteration 14 error = 0.008902778039269572
# iteration 15 error = 0.005253139648736518
# iteration 16 error = 0.0036278218041328443
# iteration 17 error = 0.003428400291594467
# iteration 18 error = 0.0028450519844320176
# iteration 19 error = 0.0016429159153719848
# iteration 20 error = 0.0009827947220073345
# iteration 21 error = 0.0007749029514903254
# iteration 22 error = 0.000764870371737188
# iteration 23 error = 0.0006709756437152965
# iteration 24 error = 0.0005771356667904868
# iteration 25 error = 0.0006683361571334608
# iteration 26 error = 0.0008032305022337637
# iteration 27 error = 0.0006534603939062878
# iteration 28 error = 0.0005133071281992027
# iteration 29 error = 0.00047842104512356247
# iteration 30 error = 0.00039506574199546995
# iteration 31 error = 0.00028541829947607183
# iteration 32 error = 0.00022409898796136156
# iteration 33 error = 0.00017732907052698383
# iteration 34 error = 0.0001272663107060146
# iteration 35 error = 8.929088054923217e-05
# iteration 36 error = 6.980203083747131e-05
# iteration 37 error = 6.181608195119029e-05
# iteration 38 error = 5.464195779941143e-05
# iteration 39 error = 5.289771922195395e-05
# iteration 40 error = 6.089062156429341e-05
# iteration 41 error = 6.5386281833441e-05
# iteration 42 error = 5.7813094981229076e-05
# iteration 43 error = 5.2268289360348794e-05
# iteration 44 error = 4.3960408313939056e-05
# iteration 45 error = 3.2667800520855534e-05
# iteration 46 error = 2.5370386191188318e-05
# iteration 47 error = 2.041573830724684e-05
# iteration 48 error = 1.516148332784345e-05
# iteration 49 error = 1.1406618383304351e-05
# iteration 50 error = 8.859358180112326e-06
# iteration 51 error = 7.179486733058921e-06
# iteration 52 error = 6.023936801417177e-06
# iteration 53 error = 5.403750461985633e-06
# iteration 54 error = 5.331578421158496e-06
# iteration 55 error = 5.765987960835161e-06
# iteration 56 error = 5.937228512796833e-06
# iteration 57 error = 5.898003574384217e-06
# iteration 58 error = 5.278060730438225e-06
# iteration 59 error = 4.229937197450788e-06
# iteration 60 error = 3.344838401838975e-06
# iteration 61 error = 2.6271647914214013e-06
# iteration 62 error = 1.8998421223128172e-06
# iteration 63 error = 1.4714466456089819e-06
# iteration 64 error = 1.177958741363301e-06
# iteration 65 error = 8.949007592084352e-07
# iteration 66 error = 7.078765473044514e-07
# iteration 67 error = 6.287189706660909e-07
# iteration 68 error = 5.516359267792275e-07
# iteration 69 error = 5.156782093443413e-07
# iteration 70 error = 5.346323447955557e-07
# iteration 71 error = 5.827673264080774e-07
# iteration 72 error = 5.800984296516413e-07
# iteration 73 error = 5.22252807407928e-07
# iteration 74 error = 4.3983703324949364e-07
# iteration 75 error = 3.595170602656442e-07
# iteration 76 error = 2.6158958580851484e-07
# iteration 77 error = 1.9230961138963653e-07
# iteration 78 error = 1.4741448202299882e-07
# iteration 79 error = 1.0991307091966425e-07
# iteration 80 error = 8.337337432687692e-08
# iteration 81 error = 7.232206212740477e-08
# iteration 82 error = 6.199806148732616e-08
# iteration 83 error = 5.371154081527754e-08
# iteration 84 error = 5.21879547877063e-08
# iteration 85 error = 5.4712493562448196e-08
# iteration 86 error = 5.608986383381366e-08
# iteration 87 error = 5.672326113271782e-08
# iteration 88 error = 5.1946043917389705e-08
# iteration 89 error = 4.410918359261564e-08
# iteration 90 error = 3.511401079618716e-08
# iteration 91 error = 2.663031839244591e-08
# iteration 92 error = 1.8951918353070544e-08
# iteration 93 error = 1.3152905335215195e-08
# iteration 94 error = 9.618737285338558e-09
# iteration 95 error = 8.093610893086151e-09
# iteration 96 error = 6.811635910504001e-09
# iteration 97 error = 5.7900638895022944e-09
# iteration 98 error = 5.4602162273926146e-09
# iteration 99 error = 5.586077896403939e-09
# iteration 100 error = 5.523323029994341e-09
# iteration 101 error = 5.648202489740975e-09
# iteration 102 error = 5.468007785778505e-09
# iteration 103 error = 4.885497925199196e-09
# iteration 104 error = 4.18755206785986e-09
# iteration 105 error = 3.380147316143261e-09
# iteration 106 error = 2.4536855569629126e-09
# iteration 107 error = 1.749870924905072e-09
# iteration 0 error = 0.005650435159242559
# iteration 1 error = 0.012342723802750387
# iteration 2 error = 0.016638283056539922
# iteration 3 error = 0.02104817067833246
# iteration 4 error = 0.03184050661759549
# iteration 5 error = 0.032472348354264415
# iteration 6 error = 0.04176894517811365
# iteration 7 error = 0.035390398608005316
# iteration 8 error = 0.028073422308613715
# iteration 9 error = 0.024601540165353836
# iteration 10 error = 0.023245152617876217
# iteration 11 error = 0.022035926205062055
# iteration 12 error = 0.025111453840639095
# iteration 13 error = 0.030573675990625767
# iteration 14 error = 0.027642219462952203
# iteration 15 error = 0.027856686148103313
# iteration 16 error = 0.026673620289650438
# iteration 17 error = 0.020757337330772185
# iteration 18 error = 0.020706104580730807
# iteration 19 error = 0.021487957642758775
# iteration 20 error = 0.020405185251603748
# iteration 21 error = 0.02284365628081905
# iteration 22 error = 0.02431376350689035
# iteration 23 error = 0.021326508633418954
# iteration 24 error = 0.02040061365053031
# iteration 25 error = 0.020007580574553617
# iteration 26 error = 0.016749370776988876
# iteration 27 error = 0.01817982106080707
# iteration 28 error = 0.018399769329020127
# iteration 29 error = 0.019240858180789817
# iteration 30 error = 0.018728480755506177
# iteration 31 error = 0.019503641383118445
# iteration 32 error = 0.01685164517236687
# iteration 33 error = 0.015632781038146065
# iteration 34 error = 0.01577262082607106
# iteration 35 error = 0.014413921910321587
# iteration 36 error = 0.015137987435205464
# iteration 37 error = 0.015385720196194573
# iteration 38 error = 0.015175091488373604
# iteration 39 error = 0.014414932636553045
# iteration 40 error = 0.0137871232480128
# iteration 41 error = 0.01285963553315953
# iteration 42 error = 0.01208199689881753
# iteration 43 error = 0.011991530722679193
# iteration 44 error = 0.012074546007140167
# iteration 45 error = 0.011838124711134861
# iteration 46 error = 0.012030000673507983
# iteration 47 error = 0.01152260816838155
# iteration 48 error = 0.0106180181185657
# iteration 49 error = 0.009929407601508075
# iteration 50 error = 0.009600180180091676
# iteration 51 error = 0.009187774630513694
# iteration 52 error = 0.009177396021178829
# iteration 53 error = 0.009229586354838533
# iteration 54 error = 0.008807402280857525
# iteration 55 error = 0.008487106465355285
# iteration 56 error = 0.007931996699710722
# iteration 57 error = 0.007312894002512498
# iteration 58 error = 0.006981153166382655
# iteration 59 error = 0.0066634350815075434
# iteration 60 error = 0.006499880649971057
# iteration 61 error = 0.006390094211290581
# iteration 62 error = 0.006015757004574466
# iteration 63 error = 0.005702720274577523
# iteration 64 error = 0.005199606229433982
# iteration 65 error = 0.00485228728940252
# iteration 66 error = 0.004442670145694264
# iteration 67 error = 0.004249231831049249
# iteration 68 error = 0.004049762983715925
# iteration 69 error = 0.0038360598907019945
# iteration 70 error = 0.0036127380695620695
# iteration 71 error = 0.0032117935577384324
# iteration 72 error = 0.0028886539675488407
# iteration 73 error = 0.002550287693337503
# iteration 74 error = 0.002262774472209252
# iteration 75 error = 0.001982190622972875
# iteration 76 error = 0.0017617595284531167
# iteration 77 error = 0.0015749642709352888
# iteration 78 error = 0.0013280571303210273
# iteration 79 error = 0.0011506150111077129
# iteration 80 error = 0.0009592384688332128
# iteration 81 error = 0.0008124540010121888
# iteration 82 error = 0.0006914455482227951
# iteration 83 error = 0.0006354597941827167
# iteration 84 error = 0.0005780093951244705
# iteration 85 error = 0.0005670375362376937
# iteration 86 error = 0.0005604396492866963
# iteration 87 error = 0.0005660442616739104
# iteration 88 error = 0.0005887018245487707
# iteration 89 error = 0.0006158880670099269
# iteration 90 error = 0.0006015871478484653
# iteration 91 error = 0.0005719862329053196
# iteration 92 error = 0.0005388444650195857
# iteration 93 error = 0.0005308185496992339
# iteration 94 error = 0.0004995994777676195
# iteration 95 error = 0.00042943530351801566
# iteration 96 error = 0.00033455594772353544
# iteration 97 error = 0.00027113371345944865
# iteration 98 error = 0.00026150919559599653
# iteration 99 error = 0.0002766532483484919
# iteration 100 error = 0.00026038581343457357
# iteration 101 error = 0.00022650819054419083
# iteration 102 error = 0.00021636453278774
# iteration 103 error = 0.0002281264397076648
# iteration 104 error = 0.0002303071537152517
# iteration 105 error = 0.00019533800450832826
# iteration 106 error = 0.0001578897046575569
# iteration 107 error = 0.0001390576896839195
# iteration 108 error = 0.000128641185007558
# iteration 109 error = 0.00011331597887874315
# iteration 110 error = 0.00010406193774688659
# iteration 111 error = 0.00010761563532682955
# iteration 112 error = 0.00010615840261392317
# iteration 113 error = 9.516229303523102e-05
# iteration 114 error = 8.503012509638837e-05
# iteration 115 error = 8.564723353461174e-05
# iteration 116 error = 8.10354922128786e-05
# iteration 117 error = 7.315445890499981e-05
# iteration 118 error = 6.45874469723392e-05
# iteration 119 error = 5.7781595006061065e-05
# iteration 120 error = 5.160290340030562e-05
# iteration 121 error = 4.605167538997966e-05
# iteration 122 error = 4.411064190826485e-05
# iteration 123 error = 4.4236837396829885e-05
# iteration 124 error = 4.2012424226227074e-05
# iteration 125 error = 3.7409016104557426e-05
# iteration 126 error = 3.369109838768997e-05
# iteration 127 error = 3.0883811925747584e-05
# iteration 128 error = 2.748315770144877e-05
# iteration 129 error = 2.5079472821819087e-05
# iteration 130 error = 2.3629180177734274e-05
# iteration 131 error = 2.2301759293678447e-05
# iteration 132 error = 2.041049270144931e-05
# iteration 133 error = 1.979908282656325e-05
# iteration 134 error = 1.9820611843149858e-05
# iteration 135 error = 1.915979524378391e-05
# iteration 136 error = 1.8143616341460435e-05
# iteration 137 error = 1.7228547755720964e-05
# iteration 138 error = 1.5654498875702514e-05
# iteration 139 error = 1.4541282145033765e-05
# iteration 140 error = 1.4323352177954557e-05
# iteration 141 error = 1.4931330290700216e-05
# iteration 142 error = 1.5997745527150972e-05
# iteration 143 error = 1.7090842801148096e-05
# iteration 144 error = 1.8265334593171287e-05
# iteration 145 error = 1.8270249128778394e-05
# iteration 146 error = 1.7750238278610816e-05
# iteration 147 error = 1.8102805554164322e-05
# iteration 148 error = 1.84229979740817e-05
# iteration 149 error = 1.8870190580577582e-05
# iteration 150 error = 1.9522876872882882e-05
# iteration 151 error = 1.978248100198833e-05
# iteration 152 error = 1.9857889903285288e-05
# iteration 153 error = 1.953539822894944e-05
# iteration 154 error = 1.9384098767268957e-05
# iteration 155 error = 1.831834968697664e-05
# iteration 156 error = 1.683659945427756e-05
# iteration 157 error = 1.5110292068761087e-05
# iteration 158 error = 1.3560019712839824e-05
# iteration 159 error = 1.1598742858204093e-05
# iteration 160 error = 1.0237495781264249e-05
# iteration 161 error = 9.243292704810306e-06
# iteration 162 error = 8.503027914937924e-06
# iteration 163 error = 7.68031150770447e-06
# iteration 164 error = 6.789562994058824e-06
# iteration 165 error = 5.920752931398556e-06
# iteration 166 error = 5.109862104171521e-06
# iteration 167 error = 4.462862426750999e-06
# iteration 168 error = 4.097945709307044e-06
# iteration 169 error = 3.826751203656419e-06
# iteration 170 error = 3.6179200445892114e-06
# iteration 171 error = 3.393166274328039e-06
# iteration 172 error = 3.184229378592074e-06
# iteration 173 error = 2.9212944409812127e-06
# iteration 174 error = 2.712938368511137e-06
# iteration 175 error = 2.5693633194500425e-06
# iteration 176 error = 2.4344453848495866e-06
# iteration 177 error = 2.337750851600405e-06
# iteration 178 error = 2.325417412546408e-06
# iteration 179 error = 2.4293513624900127e-06
# iteration 180 error = 2.5265809212488924e-06
# iteration 181 error = 2.645488206663269e-06
# iteration 182 error = 2.8452393156182365e-06
# iteration 183 error = 3.045084126987519e-06
# iteration 184 error = 3.1829421557453295e-06
# iteration 185 error = 3.1345248359742893e-06
# iteration 186 error = 2.9687018290346197e-06
# iteration 187 error = 2.7809887094192993e-06
# iteration 188 error = 2.6608575614674727e-06
# iteration 189 error = 2.5419508926537054e-06
# iteration 190 error = 2.3816927786609286e-06
# iteration 191 error = 2.1749919295307523e-06
# iteration 192 error = 2.0011477581470653e-06
# iteration 193 error = 1.8304676515767864e-06
# iteration 194 error = 1.7181176802538288e-06
# iteration 195 error = 1.6186680656578383e-06
# iteration 196 error = 1.4784883308057142e-06
# iteration 197 error = 1.3757545864690943e-06
# iteration 198 error = 1.3181232331514686e-06
# iteration 199 error = 1.235548063267798e-06
# iteration 200 error = 1.0922272228036038e-06
# iteration 201 error = 9.718524254204511e-07
# iteration 202 error = 8.753540571535761e-07
# iteration 203 error = 8.26880346932988e-07
# iteration 204 error = 7.823142844871684e-07
# iteration 205 error = 7.74391472918749e-07
# iteration 206 error = 7.667921021139706e-07
# iteration 207 error = 7.554834525920019e-07
# iteration 208 error = 7.281480693123035e-07
# iteration 209 error = 6.851474237493538e-07
# iteration 210 error = 6.381896591182e-07
# iteration 211 error = 5.971141420942307e-07
# iteration 212 error = 5.490101078767069e-07
# iteration 213 error = 5.007242432114405e-07
# iteration 214 error = 4.6734009665636443e-07
# iteration 215 error = 4.408120057255136e-07
# iteration 216 error = 4.189326545216697e-07
# iteration 217 error = 4.0333031749215906e-07
# iteration 218 error = 3.9551082173146423e-07
# iteration 219 error = 3.839820607645746e-07
# iteration 220 error = 3.619666115858334e-07
# iteration 221 error = 3.2557281708434725e-07
# iteration 222 error = 2.9345169463065523e-07
# iteration 223 error = 2.740470680899318e-07
# iteration 224 error = 2.660275330827277e-07
# iteration 225 error = 2.614012015570703e-07
# iteration 226 error = 2.566305883380649e-07
# iteration 227 error = 2.5699969727679914e-07
# iteration 228 error = 2.506415536261108e-07
# iteration 229 error = 2.4251495839697973e-07
# iteration 230 error = 2.3358662840894718e-07
# iteration 231 error = 2.267470025896879e-07
# iteration 232 error = 2.1704962319642428e-07
# iteration 233 error = 2.0164444633169686e-07
# iteration 234 error = 1.8710519189385236e-07
# iteration 235 error = 1.7018228870671423e-07
# iteration 236 error = 1.5130990588214394e-07
# iteration 237 error = 1.3572061039037744e-07
# iteration 238 error = 1.217695688526135e-07
# iteration 239 error = 1.1110757439906477e-07
# iteration 240 error = 1.0011941949247747e-07
# iteration 241 error = 9.253702393883617e-08
# iteration 242 error = 8.535248902327916e-08
# iteration 243 error = 8.060694048113837e-08
# iteration 244 error = 7.577206987199632e-08
# iteration 245 error = 7.122296567511384e-08
# iteration 246 error = 6.664829391576657e-08
# iteration 247 error = 6.31373314121634e-08
# iteration 248 error = 6.164310341790284e-08
# iteration 249 error = 6.181968323299063e-08
# iteration 250 error = 6.145637114222518e-08
# iteration 251 error = 5.980215899661558e-08
# iteration 252 error = 5.7766899558372915e-08
# iteration 253 error = 5.579372688632707e-08
# iteration 254 error = 5.1868278584748475e-08
# iteration 255 error = 4.645194639018049e-08
# iteration 256 error = 4.113358302556142e-08
# iteration 257 error = 3.6034756475221356e-08
# iteration 258 error = 3.131943329425025e-08
# iteration 259 error = 2.7960623816057856e-08
# iteration 260 error = 2.528121367500442e-08
# iteration 261 error = 2.3396120198561293e-08
# iteration 262 error = 2.1432952723447858e-08
# iteration 263 error = 1.985389275661508e-08
# iteration 264 error = 1.8339188892330383e-08
# iteration 265 error = 1.703270333713104e-08
# iteration 266 error = 1.5805438371428618e-08
# iteration 267 error = 1.502937595848539e-08
# iteration 268 error = 1.4568465793352464e-08
# iteration 269 error = 1.3902415125143214e-08
# iteration 270 error = 1.3016935083254795e-08
# iteration 271 error = 1.1643994725465854e-08
# iteration 272 error = 1.0356251819276851e-08
# iteration 273 error = 8.959438320222702e-09
# iteration 274 error = 7.890993367714633e-09
# iteration 275 error = 7.1286986136952336e-09
# iteration 276 error = 6.515760963532179e-09
# iteration 277 error = 5.950690928645973e-09
# iteration 278 error = 5.5118272438038675e-09
# iteration 279 error = 5.038528896030357e-09
# iteration 280 error = 4.741325061845059e-09
# iteration 281 error = 4.40989677947326e-09
# iteration 282 error = 4.107250154512068e-09
# iteration 283 error = 3.857539140899805e-09
# iteration 284 error = 3.695724579068895e-09
# iteration 285 error = 3.5204269328979944e-09
# iteration 286 error = 3.2795263109046217e-09
# iteration 287 error = 2.9939240928437904e-09
# iteration 288 error = 2.7917148965454675e-09
# iteration 289 error = 2.6251470653448957e-09
# iteration 290 error = 2.4404328997763727e-09
# iteration 291 error = 2.32477442594156e-09
# iteration 292 error = 2.193192917705166e-09
# iteration 293 error = 2.1019192555096283e-09
# iteration 294 error = 2.0432550260958674e-09
# iteration 295 error = 1.974324192924366e-09
# iteration 296 error = 1.9220725667412407e-09
# iteration 297 error = 1.79202436058982e-09
# iteration 298 error = 1.6213993129416119e-09
# iteration 299 error = 1.4404340161005528e-09
# iteration 300 error = 1.2421890272809682e-09
# iteration 301 error = 1.0909876208285098e-09
# iteration 302 error = 9.64060868993088e-10
# iteration 303 error = 8.687393948434968e-10
# iteration 304 error = 7.99400595407146e-10
# iteration 305 error = 7.238075192523187e-10
# iteration 306 error = 6.456051794864982e-10
# iteration 307 error = 5.79974621233266e-10
# iteration 308 error = 5.235208086787054e-10
# iteration 309 error = 4.821374789264208e-10
# iteration 310 error = 4.516930209726266e-10
# iteration 311 error = 4.2718665336125955e-10
# iteration 312 error = 4.152615606342422e-10
# iteration 313 error = 4.0557583851373246e-10
# iteration 314 error = 3.9808509247262624e-10
# iteration 315 error = 3.818342928020346e-10
# iteration 316 error = 3.6289495146917177e-10
# iteration 317 error = 3.469797528972187e-10
# iteration 318 error = 3.2732241455783393e-10
# iteration 319 error = 3.0270737477750167e-10
# iteration 320 error = 2.851404778363189e-10
# iteration 321 error = 2.6964386732070485e-10
# iteration 322 error = 2.5724830263547875e-10
# iteration 323 error = 2.5189768205142574e-10
# iteration 324 error = 2.511678880692817e-10
# iteration 325 error = 2.534130143882038e-10
# iteration 326 error = 2.5920350316345296e-10
# iteration 327 error = 2.653019066744723e-10
# iteration 328 error = 2.7387736767635837e-10
# iteration 329 error = 2.778722387509687e-10
# iteration 330 error = 2.781604838417388e-10
# iteration 331 error = 2.707532703458898e-10
# iteration 332 error = 2.609933160963098e-10
# iteration 333 error = 2.4645276473548224e-10
# iteration 334 error = 2.3334260302715885e-10
# iteration 335 error = 2.1505584249355703e-10
# iteration 336 error = 2.0555768918401244e-10
# iteration 337 error = 1.9918158266902376e-10
# iteration 338 error = 1.9251353119491492e-10
# iteration 339 error = 1.8655716266465317e-10
# iteration 340 error = 1.8653827712389526e-10
# iteration 341 error = 1.879847276889357e-10
# iteration 342 error = 1.9010326794407925e-10
# iteration 343 error = 1.8932945360408782e-10
# iteration 344 error = 1.9095848671440322e-10
# iteration 345 error = 1.9203585161987641e-10
# iteration 346 error = 1.8924735316424204e-10
# iteration 347 error = 1.8388341350788224e-10
# iteration 348 error = 1.7715266819073295e-10
# iteration 349 error = 1.6866309502692734e-10
# iteration 350 error = 1.588357117661408e-10
# iteration 351 error = 1.483161898594951e-10
# iteration 352 error = 1.3939321686909279e-10
# iteration 353 error = 1.3206162524022277e-10
# iteration 354 error = 1.2364006306918124e-10
# iteration 355 error = 1.171813353539941e-10
# iteration 356 error = 1.0965998148244171e-10
# iteration 357 error = 1.0053975972142545e-10
# iteration 358 error = 9.189159336755594e-11
# iteration 359 error = 8.429107541434442e-11
# iteration 360 error = 7.759665348636954e-11
# iteration 361 error = 7.332629627197915e-11
# iteration 362 error = 7.003184180610039e-11
# iteration 363 error = 6.789553057588615e-11
# iteration 364 error = 6.510800910120494e-11
# iteration 365 error = 6.173835563783666e-11
# iteration 366 error = 5.7002254333155844e-11
# iteration 367 error = 5.355842742259314e-11
# iteration 368 error = 5.111358379732382e-11
# iteration 369 error = 4.9445491463414195e-11
# iteration 370 error = 4.764691674317174e-11
# iteration 371 error = 4.618948530622489e-11
# iteration 372 error = 4.437190460131003e-11
# iteration 373 error = 4.11569742517716e-11
# iteration 374 error = 3.735558187636445e-11
# iteration 375 error = 3.380885604676359e-11
# iteration 376 error = 3.0475109580679745e-11
# iteration 377 error = 2.8083715920154027e-11
# iteration 378 error = 2.6255344855407106e-11
# iteration 379 error = 2.4939522107608416e-11
# iteration 380 error = 2.363473867598624e-11
# iteration 381 error = 2.2354088149595158e-11
# iteration 382 error = 2.0864105465414717e-11
# iteration 383 error = 1.94226431654328e-11
# iteration 384 error = 1.775891491238703e-11
# iteration 385 error = 1.639074845128033e-11
# iteration 386 error = 1.4683870389208944e-11
# iteration 387 error = 1.3120082872553382e-11
# iteration 388 error = 1.1807728049897272e-11
# iteration 389 error = 1.086587346694784e-11
# iteration 390 error = 9.918449502338594e-12
# iteration 391 error = 9.087840443032727e-12
# iteration 392 error = 8.287994077737264e-12
# iteration 393 error = 7.645679728937962e-12
# iteration 394 error = 7.10643874166134e-12
# iteration 395 error = 6.585773936857004e-12
# iteration 396 error = 6.23972036292402e-12
# iteration 397 error = 5.9882970658220266e-12
# iteration 398 error = 5.743070947078666e-12
# iteration 399 error = 5.370272868269901e-12

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["method", "runtime solver", "runtime setup"]
table.add_row(["a)", "-"*10, "-"*10])
table.add_row(["direct inverse", aruntime_without_precond, 0])
table.add_row(["CG with Jacobi Precond", aruntime_with_precond, aruntime_precond_setup])
table.add_row(["b)", "-"*10, "-"*10])
table.add_row(["direct inverse", bruntime_without_precond, 0])
table.add_row(["CG with Jacobi Precond", bruntime_with_precond, bruntime_precond_setup])
print(table)
# Out:
# +------------------------+--------------------+---------------------+
# |         method         |   runtime solver   |    runtime setup    |
# +------------------------+--------------------+---------------------+
# |           a)           |     ----------     |      ----------     |
# |     direct inverse     | 1.6464529037475586 |          0          |
# | CG with Jacobi Precond | 0.267514705657959  |  0.1527249813079834 |
# |           b)           |     ----------     |      ----------     |
# |     direct inverse     | 1.586883783340454  |          0          |
# | CG with Jacobi Precond | 1.103736162185669  | 0.13631010055541992 |
# +------------------------+--------------------+---------------------+

# %% [markdown]
# ---
#
# # Condition number under mesh refinement

# %%
j = 0
maxlevel = 10
levels = [i for i in range(0,maxlevel)]
num_a = []
kappa_a = []
hs_a = []

mesh = Mesh(unit_square.GenerateMesh(maxh=h))
fes = H1(mesh, order=3,dirichlet=".*")
gfu_a = GridFunction(fes,name = "u_a")
ua = fes.TrialFunction()
va = fes.TestFunction()

Aa = BilinearForm(fes)
Fa = LinearForm(fes)

Aa += ua*va*dx

Fa += va*dx

Aa.Assemble()
Fa.Assemble()

c = Preconditioner(Aa,"local",test = True)


for level in levels:
    if level > 0:
        mesh.Refine()
        
    fes.Update()
    gfu_a.Update()
    h = fes.ndof
    print("maxh:",h)
    Aa.Assemble()
    Fa.Assemble()
    c.Update()
    data = []
    callback = lambda k,r: data.append((k,r))
    #gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec

    with TaskManager():
        CG (mat=Aa.mat, pre=c.mat, rhs=Fa.vec, sol=gfu_a.vec, printrates=False, maxsteps=10000, tol=1e-15, callback = callback)
    
    hs_a.append(h)
    num_a.append(len(data))
    lams = EigenValues_Preconditioner(mat=Aa.mat, pre=c)
    kappa_a.append(max(lams)/min(lams))

print("Iterations:", maxlevel)
Draw (mesh)
Draw(gfu_a)
# Out:
# maxh: 16
# maxh: 49
# maxh: 169
# maxh: 625
# maxh: 2401
# maxh: 9409
# maxh: 37249
# maxh: 148225
# maxh: 591361
# maxh: 2362369
# Iterations: 38

# %%
j = 0
num_b = []
kappa_b = []
h_base = 0.5
maxlevel = 8
levels = [i for i in range(0,maxlevel)]
hs_b = []

mesh = Mesh(unit_square.GenerateMesh(maxh=h_base))
fes = H1(mesh, order=3,dirichlet=".*")
gfu_b = GridFunction(fes,name = "u_b")
ub = fes.TrialFunction()
vb = fes.TestFunction()

Ab = BilinearForm(fes)
Fb = LinearForm(fes)

Ab += grad(ub)*grad(vb)*dx

Fb += vb*dx

Ab.Assemble()
Fb.Assemble()

c = Preconditioner(Ab,"local",test = True)


for level in levels:
    if level > 0:
        mesh.Refine()
        
       
    fes.Update()
    gfu_b.Update()
    h = fes.ndof
    print("maxh:",h)
    Ab.Assemble()
    Fb.Assemble()
    c.Update()
    # Container for storing the number of iterations performed by the CG and the error
    data = []
    # needed for the callback function
    callback = lambda k,r: data.append((k,r))
    #gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec

    with TaskManager():
        CG (mat=Ab.mat, pre=c.mat, rhs=Fb.vec, sol=gfu_b.vec, printrates=False, maxsteps=10000,tol=1e-17, callback = callback)
    
    hs_b.append(h)
    num_b.append(len(data))
    lams = EigenValues_Preconditioner(mat=Ab.mat, pre=c)
    kappa_b.append(max(lams)/min(lams))
    
print("Iterations:", maxlevel)
Draw (mesh)
Draw(gfu_b)
# Out:
# maxh: 40
# maxh: 133
# maxh: 481
# maxh: 1825
# maxh: 7105
# maxh: 28033
# maxh: 111361
# maxh: 443905
# Iterations: 8

# %%
j = 0
maxlevel = 10
levels = [i for i in range(0,maxlevel)]
num_a = []
kappa_a = []
hs = [0.5**i for i in range(10)]

for h in hs:
    mesh = Mesh(unit_square.GenerateMesh(maxh=h))
    fes = H1(mesh, order=3,dirichlet=".*")
    gfu_a = GridFunction(fes,name = "u_a")
    ua = fes.TrialFunction()
    va = fes.TestFunction()

    Aa = BilinearForm(fes)
    Fa = LinearForm(fes)

    Aa += ua*va*dx

    Fa += va*dx

    Aa.Assemble()
    Fa.Assemble()

    c = Preconditioner(Aa,"local",test = True)

    print("maxh:",h)
    Aa.Assemble()
    Fa.Assemble()
    c.Update()
    data = []
    callback = lambda k,r: data.append((k,r))
    #gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec

    with TaskManager():
        CG (mat=Aa.mat, pre=c.mat, rhs=Fa.vec, sol=gfu_a.vec, printrates=False, maxsteps=10000, tol=1e-15, callback = callback)
    
    hs_a.append(h)
    num_a.append(len(data))
    lams = EigenValues_Preconditioner(mat=Aa.mat, pre=c)
    kappa_a.append(max(lams)/min(lams))

print("Iterations:", len(hs))
Draw (mesh)
Draw(gfu_a)

# %%
j = 0
maxlevel = 10
levels = [i for i in range(0,maxlevel)]
num_b = []
kappa_b = []
hs = [0.5**i for i in range(1,10)]


for i, h in enumerate(hs):
    mesh = Mesh(unit_square.GenerateMesh(maxh=h))
    fes = H1(mesh, order=3,dirichlet=".*")
    gfu_b = GridFunction(fes,name = "u_b")
    ub = fes.TrialFunction()
    vb = fes.TestFunction()

    Ab = BilinearForm(fes)
    Fb = LinearForm(fes)

    Ab += ub*vb*dx

    Fb += vb*dx

    Ab.Assemble()
    Fb.Assemble()

    c = Preconditioner(Ab,"local",test = True)

    print(f"ref_#: {i}, maxh: {h}")
    Ab.Assemble()
    Fb.Assemble()
    c.Update()
    data = []
    callback = lambda k,r: data.append((k,r))
    #gfu_a.vec.data = Aa.mat.Inverse(fes.FreeDofs()) * Fa.vec

    with TaskManager():
        CG (mat=Ab.mat, pre=c.mat, rhs=Fb.vec, sol=gfu_b.vec, printrates=False, maxsteps=10000, tol=1e-15, callback = callback)
    
    num_b.append(len(data))
    lams = EigenValues_Preconditioner(mat=Ab.mat, pre=c)
    kappa_b.append(max(lams)/min(lams))

print("Iterations:", len(hs))
Draw (mesh)
Draw(gfu_b)
# Out:
# ref_#: 0, maxh: 0.5
# ref_#: 1, maxh: 0.25
# ref_#: 2, maxh: 0.125
# ref_#: 3, maxh: 0.0625
# ref_#: 4, maxh: 0.03125
# ref_#: 5, maxh: 0.015625
# ref_#: 6, maxh: 0.0078125
# ref_#: 7, maxh: 0.00390625
# ref_#: 8, maxh: 0.001953125
# Iterations: 9

# %%
#from IPython.display import display, Markdown, Latex
#for i in range(3):
#    display(Latex(f'$x_{i}$'))
plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(hs_a,num_a, label="eq a)")
plt.plot(hs, num_b, label="eq b)")
plt.legend()
plt.grid()
plt.xlabel("maxh", fontsize=fs_axis)
plt.ylabel(r"number of iterations CG", fontsize=fs_axis);

plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(hs_a, kappa_a, label=r"$\kappa$ for a)")
plt.plot(hs, kappa_b, label=r"$\kappa$ for b)")
plt.legend()
plt.grid()
plt.xlabel("maxh", fontsize=fs_axis)
plt.ylabel(r"$\kappa$", fontsize=fs_axis);

plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(kappa_a,num_a, label="eq a)")
plt.plot(kappa_b,num_b, label="eq b)")
plt.legend()
plt.grid()
plt.xlabel(r"$\kappa$", fontsize=fs_axis)
plt.ylabel(r"number of iterations", fontsize=fs_axis);

# %%
#from IPython.display import display, Markdown, Latex
#for i in range(3):
#    display(Latex(f'$x_{i}$'))
plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(hs_a,num_a, label="eq a)")
plt.plot(hs_b,num_b, label="eq b)")
plt.legend()
plt.grid()
plt.xlabel("maxh", fontsize=fs_axis)
plt.ylabel(r"number of iterations CG", fontsize=fs_axis);

plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(hs_a, kappa_a, label=r"$\kappa$ for a)")
plt.plot(hs_b, kappa_b, label=r"$\kappa$ for b)")
plt.legend()
plt.grid()
plt.xlabel("maxh", fontsize=fs_axis)
plt.ylabel(r"$\kappa$", fontsize=fs_axis);

plt.figure(figsize=(16,8))
fs_axis = 14
#plt.plot(kappa_a,num_a, label="eq a)")
plt.plot(kappa_b,num_b, label="eq b)")
plt.legend()
plt.grid()
plt.xlabel(r"$\kappa$", fontsize=fs_axis)
plt.ylabel(r"number of iterations", fontsize=fs_axis);

# %%
ref_b = [100+7.5/d for d in d_b]
# Out:
# [115.0,
#  130.0,
#  145.0,
#  160.0,
#  175.0,
#  190.0,
#  205.0,
#  220.0,
#  235.0,
#  250.0,
#  265.0,
#  280.0,
#  295.0,
#  310.0,
#  325.0,
#  340.0,
#  355.0,
#  370.0,
#  385.0,
#  400.0,
#  415.0,
#  430.0,
#  445.0,
#  460.0,
#  475.0,
#  490.0,
#  505.0,
#  520.0,
#  535.0,
#  550.0,
#  565.0,
#  580.0,
#  595.0,
#  610.0,
#  625.0,
#  640.0,
#  655.0,
#  670.0,
#  685.0]

# %%
plt.figure(figsize=(16,8))
fs_title= 18
fs_axis = 14
plt.title("Condition number vs h", fontsize=fs_title)
plt.grid()
plt.xlabel("maxh", fontsize=fs_axis)
#plt.ylabel(r"$\kappa_2$ ...condition number", fontsize=fs_axis);
plt.ylabel("number of iterations (of CG)", fontsize=fs_axis)
plt.plot(hs,num_a,label=r'$\kappa_2$...cond number of the massmatrix')
plt.plot(hs,num_b,label=r'$\kappa_2$...cond number of the stiffnesmatrix')
plt.plot(hs,ref_b,label=r'estimate $c+\mathcal{O}(1/h)$')
plt.legend();
